# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset("tips")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## UNIVARIATE AND BI VARIATE
# Univariate ----- just analyze a single feature in the data set \
# Bi variate ----- analyze how these 2 featires relationship is. explore 2 features of the dataset
#
#
# ## DISTRIBUTION PLOTS
# distplot---  \
# joinplot--  **USED IN BI VARAIATE PLOT  FOR 2-D PLOTS**
# pairplot -- *** USED WHEN WE VIZUALISE MORE THAN 2 FEATURES I.E FOR 3-D , 4-D ,ETC PLOTS***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
### HEATMAP FOR CORRE

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.jointplot(x='tip', y='total_bill',data= df)

# %%
sns.jointplot(x='tip', y='total_bill',data= df, kind='reg')

# %%
sns.jointplot(x='tip', y='total_bill',data= df, kind='hist')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='smoker')

# %%
sns.displot(df)

# %%
sns.displot(df,y='total_bill', hue='smoker')

# %%
sns.displot(df,x='sex', hue='smoker')

# %%
sns.displot(df['tip'], kde=True)

# %%
sns.displot(df['tip'], kde=True, bins=100)

# %% [markdown]
# # CATERGORICAL FEATURES PLOT

# %% [markdown]
# COUNT PLOT --- LIKE HISTGRAM

# %%
sns.displot(df,x='sex')

# %%
sns.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex', data=df, hue="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='day')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.barplot(data=df, x='size', y='tip')
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
## practice box plot & voilin plot next
